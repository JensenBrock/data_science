# %%
# Libraries
import os
import datetime
from datetime import date
from dateutil.relativedelta import relativedelta
import pandas as pd
import numpy as np
import json
from serpapi import GoogleSearch
from google.cloud import bigquery

# set api key
api_key = "60252ec1d2f1ed25551476bf0192f0054771e4014bd56176f9c52b8dcd54b92f"

# %%
# set dynamic outbound and return dates
current_date = date.today()
ob_date = current_date + relativedelta(months=+1)
rt_date = ob_date + relativedelta(weeks=+2)

# convert date to string
ob_date_string = ob_date.strftime("%Y-%m-%d")
rt_date_string = rt_date.strftime("%Y-%m-%d")

# %%
# get data from SerpAPI
params = {
  "api_key": api_key,
  "engine": "google_flights",
  "hl": "en",
  "departure_id": "ATL",
  "arrival_id": "LHR",
  "outbound_date": ob_date_string,
  "return_date": rt_date_string,
  "currency": "USD",
  "type": "1",
  "travel_class": "1",
  "adults": "2",
  "stops": "0",
  "bags": "1"
}

search = GoogleSearch(params)
results = search.get_dict()

# %%
results
# Out:
# {'search_metadata': {'id': '6536c23cf8f5f78ed5f7e9ba',
#   'status': 'Success',
#   'json_endpoint': 'https://serpapi.com/searches/6013314dcf183fa1/6536c23cf8f5f78ed5f7e9ba.json',
#   'created_at': '2023-10-23 18:58:04 UTC',
#   'processed_at': '2023-10-23 18:58:04 UTC',
#   'google_flights_url': 'https://www.google.com/travel/flights?hl=en',
#   'raw_html_file': 'https://serpapi.com/searches/6013314dcf183fa1/6536c23cf8f5f78ed5f7e9ba.html',
#   'prettify_html_file': 'https://serpapi.com/searches/6013314dcf183fa1/6536c23cf8f5f78ed5f7e9ba.prettify',
#   'total_time_taken': 0.9},
#  'search_parameters': {'engine': 'google_flights',
#   'hl': 'en',
#   'type': '1',
#   'departure_id': 'ATL',
#   'arrival_id': 'LHR',
#   'outbound_date': '2023-11-23',
#   'return_date': '2023-12-07',
#   'travel_class': 1,
#   'adults': 2,
#   'stops': 0,
#   'bags': 1,
#   'currency': 'USD'},
# ...

# %%
# code
shopping_data = pd.DataFrame(shopping_results)

shopping_data

table_id = "turnkey-highway-395019.climbing_shoes.shoe_data_raw"
client = bigquery.Client()
table = client.get_table(table_id)
errers = client.insert_rows_from_dataframe(table, shopping_data)
if errors == []:
    print("Data Loaded")
else:
    print(errors)
